# %% [markdown]
# # IRIS DATA PREDICTION
#
# The IRIS flower data set contains the the physical parameters of
# three species of flower — Versicolor, Setosa and Virginica.
# The numeric parameters which the dataset contains are Sepal width, Sepal length, Petal width and Petal length.
#
# In this data we will be predicting the species of the flowers based on these parameters.
# Building a machine learning project to determine the species of the flower.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn import model_selection
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LogisticRegression 
from sklearn.svm import SVC

from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier

from sklearn.metrics import accuracy_score

# %%
df=sns.load_dataset("iris")

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df.shape
# Out:
# (150, 5)

# %%
df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
df.dtypes
# Out:
# sepal_length    float64
# sepal_width     float64
# petal_length    float64
# petal_width     float64
# species          object
# dtype: object

# %%
df['species'].value_counts()
# Out:
# versicolor    50
# virginica     50
# setosa        50
# Name: species, dtype: int64

# %%
df.plot(kind='box', subplots=True, layout=(2,2), sharex=False, sharey=False)
plt.show()

# %%
sns.boxplot(x='sepal_width',y='sepal_length',data=df)

# %%
sns.boxplot(x='petal_width',y='petal_length',data=df)

# %%
sns.pairplot(df,hue='sepal_width')
# Out:
# C:\Users\Siddy\Anaconda3\lib\site-packages\numpy\core\_methods.py:140: RuntimeWarning: Degrees of freedom <= 0 for slice
#   keepdims=keepdims)
# C:\Users\Siddy\Anaconda3\lib\site-packages\numpy\core\_methods.py:132: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# C:\Users\Siddy\Anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py:487: RuntimeWarning: invalid value encountered in true_divide
#   binned = fast_linbin(X, a, b, gridsize) / (delta * nobs)
# C:\Users\Siddy\Anaconda3\lib\site-packages\statsmodels\nonparametric\kdetools.py:34: RuntimeWarning: invalid value encountered in double_scalars
#   FAC1 = 2*(np.pi*bw/RANGE)**2

# %%
fm=df1[:,0:4]
tv=df1[:,4]
fm_train,fm_test,tv_train,tv_test=model_selection.train_test_split(fm,tv,test_size=0.2,random_state=7)

# %% [markdown]
# # Logistic Regression

# %%
model=LogisticRegression()
model.fit(fm_train,tv_train)
predictions=model.predict(fm_test)
print(accuracy_score(tv_test,predictions))
# Out:
# 0.8
# C:\Users\Siddy\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\Siddy\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:469: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)

# %% [markdown]
# Support Vector Machine (SVM)

# %%
model = SVC()
model.fit(fm_train,tv_train)
predictions = model.predict(fm_test)
print(accuracy_score(tv_test, predictions))
# Out:
# 0.9333333333333333
# C:\Users\Siddy\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)

# %% [markdown]
# # RandomForest

# %%
model = RandomForestClassifier(n_estimators=5)
model.fit(fm_train,tv_train)
predictions = model.predict(fm_test)
print(accuracy_score(tv_test, predictions))
# Out:
# 0.8333333333333334

# %% [markdown]
# K – Nearest Neighbour (KNN)

# %%
model = KNeighborsClassifier()
model.fit(fm_train,tv_train)
predictions = model.predict(fm_test)
print(accuracy_score(tv_test, predictions))
# Out:
# 0.9

# %%
The Best SVC Model accuracy Score 0.933..
